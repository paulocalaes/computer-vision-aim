# %%
import boto3
from PIL import Image

# %matplotlib inline

# %%
display(Image.open('dancing.jpeg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=258x195 at 0x7F4ED7D034A8>

# %%
import io


rekognition = boto3.client('rekognition', region_name='us-west-2',aws_access_key_id='AKIA6MAWSJLYVQLJY3GF',
         aws_secret_access_key= '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')

sourceFile='dancing.jpeg'   
imageSource=open(sourceFile,'rb')
response = rekognition.detect_labels(Image={'Bytes':imageSource.read()},
        MaxLabels=10)

# %%
labels = response['Labels']
for li in labels:
    print(li['Name'])
# Out:
# Human
# Person
# Dance
# Ballet
# Ballerina
