# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
suave = cv2.GaussianBlur(img, (7, 7), 0)
canny1 = cv2.Canny(suave, 20, 60)
canny2 = cv2.Canny(suave, 70, 210)
resultado = np.vstack([
np.hstack([img, suave ]),
np.hstack([canny1, canny2])
])
plt.imshow(resultado, cmap='gray')
print(resultado.shape)
# Out:
# (386, 590)

# %%
import scipy.ndimage as ndimage
kernel = np.ones((5,5),np.uint8)
dilation = cv2.dilate(canny1,kernel,iterations = 1)

nImage = ndimage.binary_fill_holes(dilation).astype(int)
plt.imshow(nImage, cmap='gray')

# %%
masked_image = np.copy(imgOrig)

cluster = 0
B = nImage > 0

masked_image[B == 0] = [0, 0, 0]

plt.imshow(masked_image)
print(masked_image.shape)
# Out:
# (193, 295, 3)

# %%
kernel = np.ones((2,2),np.uint8)
erosion = cv2.erode(masked_image,kernel,iterations = 1)
plt.imshow(erosion, cmap='gray')
