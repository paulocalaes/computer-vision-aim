# %%
import boto3
from PIL import Image

# %matplotlib inline

# %%
display(Image.open('placa.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1140x639 at 0x7FA3C21E0400>

# %%
import io


rekognition = boto3.client('rekognition', region_name='us-west-2',aws_access_key_id='AKIA6MAWSJLYVQLJY3GF',
         aws_secret_access_key= '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')

sourceFile='placa.jpg'   
imageSource=open(sourceFile,'rb')
response = rekognition.detect_text(Image={'Bytes':imageSource.read()})

textDetections=response['TextDetections']
print ('Detected text\n----------')
for text in textDetections:
    print ('Detected text:' + text['DetectedText'])
    print ('Confidence: ' + "{:.2f}".format(text['Confidence']) + "%")
    print ('Id: {}'.format(text['Id']))
    if 'ParentId' in text:
        print ('Parent Id: {}'.format(text['ParentId']))
    print ('Type:' + text['Type'])
    print()
# Out:
# Detected text
# ----------
# Detected text:BRASIL
# Confidence: 99.97%
# Id: 0
# Type:LINE
#
# Detected text:MERCOSUL
# Confidence: 99.73%
# Id: 1
# Type:LINE
#
# Detected text:BRA2E19
# Confidence: 99.24%
# Id: 2
# Type:LINE
#
# Detected text:BR
# Confidence: 99.83%
# Id: 3
# Type:LINE
#
# Detected text:BRASIL
# Confidence: 99.97%
# Id: 4
# Parent Id: 0
# Type:WORD
#
# Detected text:MERCOSUL
# Confidence: 99.73%
# Id: 5
# Parent Id: 1
# Type:WORD
#
# Detected text:BRA2E19
# Confidence: 99.24%
# Id: 6
# Parent Id: 2
# Type:WORD
#
# Detected text:BR
# Confidence: 99.83%
# Id: 7
# Parent Id: 3
# Type:WORD
