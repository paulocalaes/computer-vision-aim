# %%
import boto3
from PIL import Image
import json

# %matplotlib inline

# %%
display(Image.open('smiling.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x469 at 0x7F18FB201C50>

# %%
import io


rekognition = boto3.client('rekognition', region_name='us-west-2',aws_access_key_id='AKIA6MAWSJLYVQLJY3GF',
         aws_secret_access_key= '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')

sourceFile='smiling.jpg'   
imageSource=open(sourceFile,'rb')
response = rekognition.detect_faces(Image={'Bytes':imageSource.read()},Attributes=['ALL'])

# %%
for faceDetail in response['FaceDetails']:
        print('The detected face is between ' + str(faceDetail['AgeRange']['Low']) 
              + ' and ' + str(faceDetail['AgeRange']['High']) + ' years old')
        print('Here are the other attributes:')
        print(json.dumps(faceDetail, indent=4, sort_keys=True))
# Out:
# The detected face is between 22 and 34 years old
# Here are the other attributes:
# {
#     "AgeRange": {
#         "High": 34,
#         "Low": 22
#     },
#     "Beard": {
#         "Confidence": 99.49020385742188,
#         "Value": false
#     },
#     "BoundingBox": {
#         "Height": 0.5054062604904175,
#         "Left": 0.2767823338508606,
#         "Top": 0.0382595919072628,
#         "Width": 0.25530341267585754
#     },
#     "Confidence": 99.99932098388672,
#     "Emotions": [
#         {
#             "Confidence": 99.31224822998047,
#             "Type": "HAPPY"
#         },
#         {
#             "Confidence": 0.18941785395145416,
#             "Type": "FEAR"
#         },
#         {
#             "Confidence": 0.1739056557416916,
#             "Type": "SURPRISED"
#         },
#         {
#             "Confidence": 0.1065726950764656,
#             "Type": "ANGRY"
#         },
#         {
#             "Confidence": 0.07713694125413895,
#             "Type": "SAD"
#         },
#         {
#             "Confidence": 0.06781639158725739,
#             "Type": "CALM"
#         },
#         {
#             "Confidence": 0.04435949772596359,
#             "Type": "DISGUSTED"
#         },
#         {
#             "Confidence": 0.02853436954319477,
#             "Type": "CONFUSED"
#         }
#     ],
#     "Eyeglasses": {
#         "Confidence": 99.88783264160156,
#         "Value": false
#     },
#     "EyesOpen": {
#         "Confidence": 69.07246398925781,
#         "Value": false
#     },
#     "Gender": {
#         "Confidence": 99.83522033691406,
#         "Value": "Female"
#     },
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.3185786008834839,
#             "Y": 0.24869215488433838
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.43938931822776794,
#             "Y": 0.205387681722641
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.3620758652687073,
#             "Y": 0.4160991609096527
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.46223294734954834,
#             "Y": 0.3795129954814911
#         },
#         {
#             "Type": "nose",
#             "X": 0.3971574902534485,
#             "Y": 0.2869204580783844
#         },
#         {
#             "Type": "leftEyeBrowLeft",
#             "X": 0.26641571521759033,
#             "Y": 0.23463039100170135
#         },
#         {
#             "Type": "leftEyeBrowRight",
#             "X": 0.29735514521598816,
#             "Y": 0.18624308705329895
#         },
#         {
#             "Type": "leftEyeBrowUp",
#             "X": 0.3341785967350006,
#             "Y": 0.17720453441143036
#         },
#         {
#             "Type": "rightEyeBrowLeft",
#             "X": 0.403525710105896,
#             "Y": 0.15243738889694214
#         },
#         {
#             "Type": "rightEyeBrowRight",
#             "X": 0.4369070529937744,
#             "Y": 0.1365548074245453
#         },
#         {
#             "Type": "rightEyeBrowUp",
#             "X": 0.4763144254684448,
#             "Y": 0.15975379943847656
#         },
#         {
#             "Type": "leftEyeLeft",
#             "X": 0.29701468348503113,
#             "Y": 0.25934362411499023
#         },
#         {
#             "Type": "leftEyeRight",
#             "X": 0.3428809940814972,
#             "Y": 0.24149715900421143
#         },
#         {
#             "Type": "leftEyeUp",
#             "X": 0.3165815472602844,
#             "Y": 0.23841312527656555
#         },
#         {
#             "Type": "leftEyeDown",
#             "X": 0.3207896649837494,
#             "Y": 0.2556457817554474
#         },
#         {
#             "Type": "rightEyeLeft",
#             "X": 0.41587844491004944,
#             "Y": 0.2154117226600647
#         },
#         {
#             "Type": "rightEyeRight",
#             "X": 0.46049851179122925,
#             "Y": 0.20075646042823792
#         },
#         {
#             "Type": "rightEyeUp",
#             "X": 0.43784111738204956,
#             "Y": 0.19495029747486115
#         },
#         {
#             "Type": "rightEyeDown",
#             "X": 0.4402380585670471,
#             "Y": 0.21275918185710907
#         },
#         {
#             "Type": "noseLeft",
#             "X": 0.37811025977134705,
#             "Y": 0.3323368728160858
#         },
#         {
#             "Type": "noseRight",
#             "X": 0.4226420223712921,
#             "Y": 0.3163757920265198
#         },
#         {
#             "Type": "mouthUp",
#             "X": 0.4082963764667511,
#             "Y": 0.36216193437576294
#         },
#         {
#             "Type": "mouthDown",
#             "X": 0.4184325039386749,
#             "Y": 0.417888879776001
#         },
#         {
#             "Type": "leftPupil",
#             "X": 0.3185786008834839,
#             "Y": 0.24869215488433838
#         },
#         {
#             "Type": "rightPupil",
#             "X": 0.43938931822776794,
#             "Y": 0.205387681722641
#         },
#         {
#             "Type": "upperJawlineLeft",
#             "X": 0.2478010058403015,
#             "Y": 0.32237595319747925
#         },
#         {
#             "Type": "midJawlineLeft",
#             "X": 0.3087008595466614,
#             "Y": 0.4927421510219574
#         },
#         {
#             "Type": "chinBottom",
#             "X": 0.4356015622615814,
#             "Y": 0.519956111907959
#         },
#         {
#             "Type": "midJawlineRight",
#             "X": 0.5222679972648621,
#             "Y": 0.4171803593635559
#         },
#         {
#             "Type": "upperJawlineRight",
#             "X": 0.5114495158195496,
#             "Y": 0.2288825809955597
#         }
#     ],
#     "MouthOpen": {
#         "Confidence": 99.21745300292969,
#         "Value": true
#     },
#     "Mustache": {
#         "Confidence": 99.89397430419922,
#         "Value": false
#     },
#     "Pose": {
#         "Pitch": 18.131881713867188,
#         "Roll": -13.024090766906738,
#         "Yaw": 2.6126980781555176
#     },
#     "Quality": {
#         "Brightness": 92.8397216796875,
#         "Sharpness": 89.85481262207031
#     },
#     "Smile": {
#         "Confidence": 98.66697692871094,
#         "Value": true
#     },
#     "Sunglasses": {
#         "Confidence": 99.97571563720703,
#         "Value": false
#     }
# }

# %%
display(Image.open('coringa.jpeg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7F18E2E754A8>

# %%
import io


rekognition = boto3.client('rekognition', region_name='us-west-2',aws_access_key_id='AKIA6MAWSJLYVQLJY3GF',
         aws_secret_access_key= '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')

sourceFile='coringa.jpeg'   
imageSource=open(sourceFile,'rb')
response = rekognition.detect_faces(Image={'Bytes':imageSource.read()},Attributes=['ALL'])
for faceDetail in response['FaceDetails']:
        print('The detected face is between ' + str(faceDetail['AgeRange']['Low']) 
              + ' and ' + str(faceDetail['AgeRange']['High']) + ' years old')
        print('Here are the other attributes:')
        print(json.dumps(faceDetail, indent=4, sort_keys=True))
# Out:
# The detected face is between 22 and 34 years old
# Here are the other attributes:
# {
#     "AgeRange": {
#         "High": 34,
#         "Low": 22
#     },
#     "Beard": {
#         "Confidence": 84.85598754882812,
#         "Value": false
#     },
#     "BoundingBox": {
#         "Height": 0.4792608916759491,
#         "Left": 0.4104108214378357,
#         "Top": 0.042161501944065094,
#         "Width": 0.34119912981987
#     },
#     "Confidence": 99.98976135253906,
#     "Emotions": [
#         {
#             "Confidence": 97.45861053466797,
#             "Type": "CALM"
#         },
#         {
#             "Confidence": 1.1226657629013062,
#             "Type": "SAD"
#         },
#         {
#             "Confidence": 0.5514941215515137,
#             "Type": "SURPRISED"
#         },
#         {
#             "Confidence": 0.31577885150909424,
#             "Type": "HAPPY"
#         },
#         {
#             "Confidence": 0.16843119263648987,
#             "Type": "ANGRY"
#         },
#         {
#             "Confidence": 0.15913048386573792,
#             "Type": "FEAR"
#         },
#         {
#             "Confidence": 0.12745198607444763,
#             "Type": "CONFUSED"
#         },
#         {
#             "Confidence": 0.09643765538930893,
#             "Type": "DISGUSTED"
#         }
#     ],
#     "Eyeglasses": {
#         "Confidence": 90.89141845703125,
#         "Value": false
#     },
#     "EyesOpen": {
#         "Confidence": 99.1291275024414,
#         "Value": true
#     },
#     "Gender": {
#         "Confidence": 78.2021484375,
#         "Value": "Male"
#     },
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.5071737170219421,
#             "Y": 0.2495558261871338
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.6571682691574097,
#             "Y": 0.2635631859302521
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.5037022829055786,
#             "Y": 0.4079305827617645
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.628836452960968,
#             "Y": 0.41973909735679626
#         },
#         {
#             "Type": "nose",
#             "X": 0.5654664635658264,
#             "Y": 0.3508114814758301
#         },
#         {
#             "Type": "leftEyeBrowLeft",
#             "X": 0.45751187205314636,
#             "Y": 0.20332451164722443
#         },
#         {
#             "Type": "leftEyeBrowRight",
#             "X": 0.4990452826023102,
#             "Y": 0.19447217881679535
#         },
#         {
#             "Type": "leftEyeBrowUp",
#             "X": 0.5401957035064697,
#             "Y": 0.20875459909439087
#         },
#         {
#             "Type": "rightEyeBrowLeft",
#             "X": 0.6258012652397156,
#             "Y": 0.21658900380134583
#         },
#         {
#             "Type": "rightEyeBrowRight",
#             "X": 0.671618640422821,
#             "Y": 0.2103363275527954
#         },
#         {
#             "Type": "rightEyeBrowUp",
#             "X": 0.7181548476219177,
#             "Y": 0.2274063676595688
#         },
#         {
#             "Type": "leftEyeLeft",
#             "X": 0.4814322590827942,
#             "Y": 0.24474985897541046
#         },
#         {
#             "Type": "leftEyeRight",
#             "X": 0.5365907549858093,
#             "Y": 0.25342950224876404
#         },
#         {
#             "Type": "leftEyeUp",
#             "X": 0.5070258975028992,
#             "Y": 0.2419746369123459
#         },
#         {
#             "Type": "leftEyeDown",
#             "X": 0.5069681406021118,
#             "Y": 0.25632545351982117
#         },
#         {
#             "Type": "rightEyeLeft",
#             "X": 0.6271046996116638,
#             "Y": 0.26185131072998047
#         },
#         {
#             "Type": "rightEyeRight",
#             "X": 0.6846731305122375,
#             "Y": 0.26371023058891296
#         },
#         {
#             "Type": "rightEyeUp",
#             "X": 0.6575552821159363,
#             "Y": 0.2559836208820343
#         },
#         {
#             "Type": "rightEyeDown",
#             "X": 0.6555342674255371,
#             "Y": 0.27019810676574707
#         },
#         {
#             "Type": "noseLeft",
#             "X": 0.540463924407959,
#             "Y": 0.3584604263305664
#         },
#         {
#             "Type": "noseRight",
#             "X": 0.5959383845329285,
#             "Y": 0.3636537790298462
#         },
#         {
#             "Type": "mouthUp",
#             "X": 0.5638408660888672,
#             "Y": 0.39933621883392334
#         },
#         {
#             "Type": "mouthDown",
#             "X": 0.560329020023346,
#             "Y": 0.4448782801628113
#         },
#         {
#             "Type": "leftPupil",
#             "X": 0.5071737170219421,
#             "Y": 0.2495558261871338
#         },
#         {
#             "Type": "rightPupil",
#             "X": 0.6571682691574097,
#             "Y": 0.2635631859302521
#         },
#         {
#             "Type": "upperJawlineLeft",
#             "X": 0.43026241660118103,
#             "Y": 0.2259361296892166
#         },
#         {
#             "Type": "midJawlineLeft",
#             "X": 0.4429679811000824,
#             "Y": 0.40088045597076416
#         },
#         {
#             "Type": "chinBottom",
#             "X": 0.5560985803604126,
#             "Y": 0.5215117335319519
#         },
#         {
#             "Type": "midJawlineRight",
#             "X": 0.7083953022956848,
#             "Y": 0.4255927503108978
#         },
#         {
#             "Type": "upperJawlineRight",
#             "X": 0.7571092844009399,
#             "Y": 0.2560838460922241
#         }
#     ],
#     "MouthOpen": {
#         "Confidence": 96.83183288574219,
#         "Value": false
#     },
#     "Mustache": {
#         "Confidence": 97.46700286865234,
#         "Value": false
#     },
#     "Pose": {
#         "Pitch": 1.506170630455017,
#         "Roll": 4.061717510223389,
#         "Yaw": -1.7153706550598145
#     },
#     "Quality": {
#         "Brightness": 59.06184387207031,
#         "Sharpness": 53.330047607421875
#     },
#     "Smile": {
#         "Confidence": 98.65522003173828,
#         "Value": false
#     },
#     "Sunglasses": {
#         "Confidence": 92.30813598632812,
#         "Value": false
#     }
# }
