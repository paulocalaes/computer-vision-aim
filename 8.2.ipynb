# %%
import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# Instantiates a client
client = vision.ImageAnnotatorClient()

# The name of the image file to annotate
file_name = ('smiling.jpg')
# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()
    
image = types.Image(content=content)
client.face_detection(image=image, max_results=10).face_annotations
# Out:
# [bounding_poly {
#   vertices {
#     x: 118
#   }
#   vertices {
#     x: 376
#   }
#   vertices {
#     x: 376
#     y: 265
#   }
#   vertices {
#     x: 118
#     y: 265
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 140
#     y: 18
#   }
#   vertices {
#     x: 348
#     y: 18
#   }
#   vertices {
#     x: 348
#     y: 237
#   }
#   vertices {
#     x: 140
#     y: 237
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 199.28976440429688
#     y: 116.06686401367188
#     z: 0.00081634521484375
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 277.4022521972656
#     y: 96.06512451171875
#     z: 0.1080465316772461
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 172.037353515625
#     y: 101.27251434326172
#     z: 10.066670417785645
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 214.67005920410156
#     y: 88.86640930175781
#     z: -11.518354415893555
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 252.3682098388672
#     y: 79.66073608398438
#     z: -11.5368013381958
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 295.7000732421875
#     y: 70.80113220214844
#     z: 10.004956245422363
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 238.05392456054688
#     y: 102.86691284179688
#     z: -15.438071250915527
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 248.52978515625
#     y: 136.81553649902344
#     z: -42.75718688964844
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 254.0291290283203
#     y: 165.4837188720703
#     z: -29.567405700683594
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 263.7038269042969
#     y: 205.82461547851562
#     z: -29.681072235107422
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 221.77691650390625
#     y: 191.79330444335938
#     z: -10.674304008483887
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 296.0830993652344
#     y: 173.3179168701172
#     z: -10.504955291748047
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 259.5799865722656
#     y: 184.4708251953125
#     z: -26.522714614868164
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 270.0516357421875
#     y: 141.23330688476562
#     z: -15.463495254516602
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 228.11439514160156
#     y: 152.82371520996094
#     z: -15.714879035949707
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 250.33042907714844
#     y: 150.94552612304688
#     z: -27.68714141845703
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 196.0072784423828
#     y: 108.85640716552734
#     z: -3.2563419342041016
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 214.6864471435547
#     y: 112.59475708007812
#     z: -0.10416889190673828
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 199.8182373046875
#     y: 121.82818603515625
#     z: -1.6492767333984375
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 183.79786682128906
#     y: 121.23128509521484
#     z: 6.884585857391357
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 277.2640075683594
#     y: 88.20216369628906
#     z: -3.2037353515625
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 292.8335876464844
#     y: 91.87881469726562
#     z: 7.174860954284668
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 280.201171875
#     y: 101.33416748046875
#     z: -1.5795373916625977
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 262.92535400390625
#     y: 101.26129150390625
#     z: -0.1472177505493164
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 190.11244201660156
#     y: 88.42542266845703
#     z: -4.560519218444824
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 273.38787841796875
#     y: 68.10585021972656
#     z: -4.612664222717285
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 164.62371826171875
#     y: 162.9012451171875
#     z: 91.46231842041016
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 332.2306823730469
#     y: 112.42355346679688
#     z: 92.60665893554688
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 233.0427703857422
#     y: 85.56171417236328
#     z: -14.41057300567627
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 272.8854064941406
#     y: 245.04046630859375
#     z: -24.64082908630371
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 187.906982421875
#     y: 220.71450805664062
#     z: 49.79579162597656
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 332.39794921875
#     y: 185.25405883789062
#     z: 50.23095703125
#   }
# }
# landmarks {
#   position {
#     x: 196.22381591796875
#     y: 168.71743774414062
#     z: 0.5237941741943359
#   }
# }
# landmarks {
#   position {
#     x: 305.7441711425781
#     y: 139.69288635253906
#     z: 0.8068141937255859
#   }
# }
# roll_angle: -14.137428283691406
# pan_angle: 0.03501978516578674
# tilt_angle: 7.014495372772217
# detection_confidence: 0.9645109176635742
# landmarking_confidence: 0.4733765423297882
# joy_likelihood: VERY_LIKELY
# sorrow_likelihood: VERY_UNLIKELY
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY
# ]
